# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import time
import psutil
import csv
import os

# %%
# -------- Force CUDA --------
if not torch.cuda.is_available():
    raise RuntimeError("CUDA is not available. Enable GPU in notebook settings.")
device = torch.device("cuda")
print(f"Using GPU: {torch.cuda.get_device_name(device)}")

# -------- Dataset and Transform --------
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  # mean, std
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)

# -------- Model Definition --------
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32 * 8 * 8, 100),
            nn.ReLU(),
            nn.Linear(100, 10)
        )

    def forward(self, x):
        x = self.conv(x)
        x = self.fc(x)
        return x

model = SimpleCNN().to(device)

# -------- Loss and Optimizer --------
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
# Out:
# Using GPU: Tesla T4

# %%
# -------- CSV Logging Setup --------
csv_file = 'pytorch_cnn_cuda.csv'
with open(csv_file, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow([
        "Epoch", "Image_Number", "Batch_Index", "Loss",
        "RAM_Usage_MB", "GPU_Alloc_MB", "Time_Per_Batch_s",
        "Train_Accuracy(%)", "Test_Accuracy(%)"
    ])

# -------- Training Loop --------
num_epochs = 10
model.train()

for epoch in range(num_epochs):
    correct_train, total_train = 0, 0

    for batch_idx, (images, labels) in enumerate(trainloader):
        start = time.perf_counter()

        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Training accuracy for this batch
        _, predicted = torch.max(outputs.data, 1)
        correct_train += (predicted == labels).sum().item()
        total_train += labels.size(0)

        end = time.perf_counter()

        # Metrics
        ram = psutil.Process(os.getpid()).memory_info().rss / (1024 * 1024)
        gpu_mem = torch.cuda.memory_allocated() / (1024 ** 2)
        elapsed = end - start
        image_number = batch_idx * images.size(0)

        # Log per-batch
        with open(csv_file, mode='a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([
                epoch + 1, image_number, batch_idx, f"{loss.item():.4f}",
                f"{ram:.2f}", f"{gpu_mem:.2f}", f"{elapsed:.6f}", "", ""
            ])

        if batch_idx % 100 == 0:
            print(f"[Epoch {epoch+1}] Image {image_number}, Batch {batch_idx}: Loss={loss.item():.4f}, RAM={ram:.2f}MB, GPU={gpu_mem:.2f}MB, Time={elapsed:.6f}s")

    # -------- Train Accuracy This Epoch --------
    train_accuracy = 100 * correct_train / total_train

    # -------- Test Accuracy This Epoch --------
    model.eval()
    correct_test, total_test = 0, 0
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            correct_test += (predicted == labels).sum().item()
            total_test += labels.size(0)

    test_accuracy = 100 * correct_test / total_test
    print(f"[Epoch {epoch+1}] Train Accuracy: {train_accuracy:.2f}% | Test Accuracy: {test_accuracy:.2f}%")
    model.train()

    # -------- Log Epoch-Level Accuracy to CSV --------
    with open(csv_file, mode='a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow([
            epoch + 1, "END", "-", "-", "-", "-", "-", f"{train_accuracy:.2f}", f"{test_accuracy:.2f}"
        ])

print(f"Final GPU Memory Used: {torch.cuda.memory_allocated() / (1024 ** 2):.2f} MB")
# Out:
# [Epoch 1] Image 0, Batch 0: Loss=2.3081, RAM=1514.60MB, GPU=18.62MB, Time=0.003213s
# [Epoch 1] Image 6400, Batch 100: Loss=2.2836, RAM=1514.73MB, GPU=18.62MB, Time=0.002523s
# [Epoch 1] Image 12800, Batch 200: Loss=2.2200, RAM=1514.73MB, GPU=18.62MB, Time=0.002529s
# [Epoch 1] Image 19200, Batch 300: Loss=2.1590, RAM=1514.73MB, GPU=18.62MB, Time=0.002546s
# [Epoch 1] Image 25600, Batch 400: Loss=2.0753, RAM=1514.73MB, GPU=18.62MB, Time=0.002537s
# [Epoch 1] Image 32000, Batch 500: Loss=2.1371, RAM=1514.73MB, GPU=18.62MB, Time=0.002512s
# [Epoch 1] Image 38400, Batch 600: Loss=2.1322, RAM=1514.73MB, GPU=18.62MB, Time=0.002599s
# [Epoch 1] Image 44800, Batch 700: Loss=1.8386, RAM=1514.73MB, GPU=18.62MB, Time=0.002604s
# [Epoch 1] Train Accuracy: 23.71% | Test Accuracy: 32.62%
# [Epoch 2] Image 0, Batch 0: Loss=1.9390, RAM=1515.23MB, GPU=18.62MB, Time=0.002873s
# [Epoch 2] Image 6400, Batch 100: Loss=1.9281, RAM=1515.23MB, GPU=18.62MB, Time=0.002609s
# [Epoch 2] Image 12800, Batch 200: Loss=1.8611, RAM=1515.23MB, GPU=18.62MB, Time=0.002696s
# [Epoch 2] Image 19200, Batch 300: Loss=1.9511, RAM=1515.23MB, GPU=18.62MB, Time=0.002819s
# [Epoch 2] Image 25600, Batch 400: Loss=1.7571, RAM=1515.23MB, GPU=18.62MB, Time=0.002628s
# [Epoch 2] Image 32000, Batch 500: Loss=1.8055, RAM=1515.23MB, GPU=18.62MB, Time=0.002585s
# [Epoch 2] Image 38400, Batch 600: Loss=1.8471, RAM=1515.23MB, GPU=18.62MB, Time=0.002582s
# [Epoch 2] Image 44800, Batch 700: Loss=1.9369, RAM=1515.23MB, GPU=18.62MB, Time=0.002609s
# [Epoch 2] Train Accuracy: 37.92% | Test Accuracy: 40.42%
# [Epoch 3] Image 0, Batch 0: Loss=1.6863, RAM=1515.23MB, GPU=18.62MB, Time=0.002744s
# [Epoch 3] Image 6400, Batch 100: Loss=1.4789, RAM=1515.23MB, GPU=18.62MB, Time=0.002688s
# [Epoch 3] Image 12800, Batch 200: Loss=1.5689, RAM=1515.23MB, GPU=18.62MB, Time=0.002624s
# [Epoch 3] Image 19200, Batch 300: Loss=1.6495, RAM=1515.23MB, GPU=18.62MB, Time=0.002577s
# [Epoch 3] Image 25600, Batch 400: Loss=1.7501, RAM=1515.23MB, GPU=18.62MB, Time=0.002658s
# [Epoch 3] Image 32000, Batch 500: Loss=1.8323, RAM=1515.23MB, GPU=18.62MB, Time=0.002655s
# [Epoch 3] Image 38400, Batch 600: Loss=1.4652, RAM=1515.23MB, GPU=18.62MB, Time=0.002547s
# [Epoch 3] Image 44800, Batch 700: Loss=1.5329, RAM=1515.23MB, GPU=18.62MB, Time=0.002617s
# [Epoch 3] Train Accuracy: 44.66% | Test Accuracy: 46.12%
# [Epoch 4] Image 0, Batch 0: Loss=1.4721, RAM=1515.23MB, GPU=18.62MB, Time=0.002708s
# [Epoch 4] Image 6400, Batch 100: Loss=1.4828, RAM=1515.23MB, GPU=18.62MB, Time=0.002614s
# [Epoch 4] Image 12800, Batch 200: Loss=1.5538, RAM=1515.23MB, GPU=18.62MB, Time=0.002558s
# [Epoch 4] Image 19200, Batch 300: Loss=1.3904, RAM=1515.23MB, GPU=18.62MB, Time=0.002763s
# [Epoch 4] Image 25600, Batch 400: Loss=1.5882, RAM=1515.23MB, GPU=18.62MB, Time=0.002635s
# [Epoch 4] Image 32000, Batch 500: Loss=1.3265, RAM=1515.23MB, GPU=18.62MB, Time=0.002674s
# [Epoch 4] Image 38400, Batch 600: Loss=1.3536, RAM=1515.23MB, GPU=18.62MB, Time=0.002871s
# [Epoch 4] Image 44800, Batch 700: Loss=1.3827, RAM=1515.23MB, GPU=18.62MB, Time=0.002616s
# [Epoch 4] Train Accuracy: 49.05% | Test Accuracy: 48.14%
# [Epoch 5] Image 0, Batch 0: Loss=1.4887, RAM=1515.23MB, GPU=18.62MB, Time=0.002894s
# [Epoch 5] Image 6400, Batch 100: Loss=1.3550, RAM=1515.23MB, GPU=18.62MB, Time=0.002675s
# [Epoch 5] Image 12800, Batch 200: Loss=1.3441, RAM=1515.23MB, GPU=18.62MB, Time=0.002600s
# [Epoch 5] Image 19200, Batch 300: Loss=1.4738, RAM=1515.23MB, GPU=18.62MB, Time=0.002595s
# [Epoch 5] Image 25600, Batch 400: Loss=1.2511, RAM=1515.23MB, GPU=18.62MB, Time=0.002684s
# [Epoch 5] Image 32000, Batch 500: Loss=1.0997, RAM=1515.23MB, GPU=18.62MB, Time=0.002668s
# [Epoch 5] Image 38400, Batch 600: Loss=1.3718, RAM=1515.23MB, GPU=18.62MB, Time=0.002734s
# [Epoch 5] Image 44800, Batch 700: Loss=1.4088, RAM=1515.23MB, GPU=18.62MB, Time=0.002565s
# [Epoch 5] Train Accuracy: 52.11% | Test Accuracy: 52.22%
# [Epoch 6] Image 0, Batch 0: Loss=1.2445, RAM=1515.23MB, GPU=18.62MB, Time=0.002706s
# [Epoch 6] Image 6400, Batch 100: Loss=1.3134, RAM=1515.23MB, GPU=18.62MB, Time=0.002590s
# [Epoch 6] Image 12800, Batch 200: Loss=1.2650, RAM=1515.23MB, GPU=18.62MB, Time=0.002601s
# [Epoch 6] Image 19200, Batch 300: Loss=1.1876, RAM=1515.23MB, GPU=18.62MB, Time=0.002655s
# [Epoch 6] Image 25600, Batch 400: Loss=1.1487, RAM=1515.23MB, GPU=18.62MB, Time=0.002586s
# [Epoch 6] Image 32000, Batch 500: Loss=1.0937, RAM=1515.23MB, GPU=18.62MB, Time=0.002532s
# [Epoch 6] Image 38400, Batch 600: Loss=1.1273, RAM=1515.23MB, GPU=18.62MB, Time=0.002593s
# [Epoch 6] Image 44800, Batch 700: Loss=1.4181, RAM=1515.23MB, GPU=18.62MB, Time=0.002658s
# [Epoch 6] Train Accuracy: 54.95% | Test Accuracy: 54.18%
# [Epoch 7] Image 0, Batch 0: Loss=1.3316, RAM=1515.23MB, GPU=18.62MB, Time=0.002740s
# [Epoch 7] Image 6400, Batch 100: Loss=1.2621, RAM=1515.23MB, GPU=18.62MB, Time=0.002584s
# [Epoch 7] Image 12800, Batch 200: Loss=1.2945, RAM=1515.23MB, GPU=18.62MB, Time=0.002646s
# [Epoch 7] Image 19200, Batch 300: Loss=1.2474, RAM=1515.23MB, GPU=18.62MB, Time=0.002611s
# [Epoch 7] Image 25600, Batch 400: Loss=1.4622, RAM=1515.23MB, GPU=18.62MB, Time=0.002609s
# [Epoch 7] Image 32000, Batch 500: Loss=1.1171, RAM=1515.23MB, GPU=18.62MB, Time=0.003258s
# [Epoch 7] Image 38400, Batch 600: Loss=1.1300, RAM=1515.23MB, GPU=18.62MB, Time=0.002541s
# [Epoch 7] Image 44800, Batch 700: Loss=1.4899, RAM=1515.23MB, GPU=18.62MB, Time=0.002577s
# [Epoch 7] Train Accuracy: 56.74% | Test Accuracy: 55.71%
# [Epoch 8] Image 0, Batch 0: Loss=1.1873, RAM=1515.23MB, GPU=18.62MB, Time=0.002713s
# [Epoch 8] Image 6400, Batch 100: Loss=1.1513, RAM=1515.23MB, GPU=18.62MB, Time=0.002634s
# [Epoch 8] Image 12800, Batch 200: Loss=1.2603, RAM=1515.23MB, GPU=18.62MB, Time=0.002705s
# [Epoch 8] Image 19200, Batch 300: Loss=1.0850, RAM=1515.23MB, GPU=18.62MB, Time=0.002627s
# [Epoch 8] Image 25600, Batch 400: Loss=1.0852, RAM=1515.23MB, GPU=18.62MB, Time=0.002567s
# [Epoch 8] Image 32000, Batch 500: Loss=1.2084, RAM=1515.23MB, GPU=18.62MB, Time=0.002664s
# [Epoch 8] Image 38400, Batch 600: Loss=1.0637, RAM=1515.23MB, GPU=18.62MB, Time=0.002638s
# [Epoch 8] Image 44800, Batch 700: Loss=0.9136, RAM=1515.23MB, GPU=18.62MB, Time=0.002641s
# [Epoch 8] Train Accuracy: 59.05% | Test Accuracy: 53.31%
# [Epoch 9] Image 0, Batch 0: Loss=1.2015, RAM=1515.23MB, GPU=18.62MB, Time=0.002753s
# [Epoch 9] Image 6400, Batch 100: Loss=1.0126, RAM=1515.23MB, GPU=18.62MB, Time=0.002637s
# [Epoch 9] Image 12800, Batch 200: Loss=1.3917, RAM=1515.23MB, GPU=18.62MB, Time=0.002542s
# [Epoch 9] Image 19200, Batch 300: Loss=1.1720, RAM=1515.23MB, GPU=18.62MB, Time=0.002538s
# [Epoch 9] Image 25600, Batch 400: Loss=1.1165, RAM=1515.23MB, GPU=18.62MB, Time=0.002638s
# [Epoch 9] Image 32000, Batch 500: Loss=1.0386, RAM=1515.23MB, GPU=18.62MB, Time=0.002672s
# [Epoch 9] Image 38400, Batch 600: Loss=0.8392, RAM=1515.23MB, GPU=18.62MB, Time=0.002649s
# [Epoch 9] Image 44800, Batch 700: Loss=0.9362, RAM=1515.23MB, GPU=18.62MB, Time=0.002530s
# [Epoch 9] Train Accuracy: 60.30% | Test Accuracy: 57.41%
# [Epoch 10] Image 0, Batch 0: Loss=1.0511, RAM=1515.23MB, GPU=18.62MB, Time=0.002768s
# [Epoch 10] Image 6400, Batch 100: Loss=1.0152, RAM=1515.23MB, GPU=18.62MB, Time=0.002554s
# [Epoch 10] Image 12800, Batch 200: Loss=1.2792, RAM=1515.23MB, GPU=18.62MB, Time=0.002572s
# [Epoch 10] Image 19200, Batch 300: Loss=1.2967, RAM=1515.23MB, GPU=18.62MB, Time=0.002619s
# [Epoch 10] Image 25600, Batch 400: Loss=1.0906, RAM=1515.23MB, GPU=18.62MB, Time=0.002509s
# [Epoch 10] Image 32000, Batch 500: Loss=1.3287, RAM=1515.23MB, GPU=18.62MB, Time=0.002533s
# [Epoch 10] Image 38400, Batch 600: Loss=1.1727, RAM=1515.23MB, GPU=18.62MB, Time=0.002542s
# [Epoch 10] Image 44800, Batch 700: Loss=1.2766, RAM=1515.23MB, GPU=18.62MB, Time=0.002530s
# [Epoch 10] Train Accuracy: 62.16% | Test Accuracy: 58.85%
# Final GPU Memory Used: 18.05 MB
